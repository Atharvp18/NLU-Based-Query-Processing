# %% [markdown]
# # CODE TO ADD INTENTS

# %%
# Entities are already added through the wit.ai website

import requests
import time
import random
import json

# Define your Wit.ai access token and app ID
WITAI_ACCESS_TOKEN = 'MWLBURSN7OWE4F2ANHQ2P7L7QZVNJ6DH'
WITAI_APP_ID = '1063283911477629'

# Define the Wit.ai API endpoint for training
TRAINING_ENDPOINT = 'https://api.wit.ai/intents?v=20230215'

headers = {
        'Authorization': f'Bearer {WITAI_ACCESS_TOKEN}',
        'Content-Type': 'application/json',
    }

intents = [
    {
        "name": "retrieve_case01",
    },
    {
        "name": "retrieve_statute03",
    },
    {
        "name": "retrieve_date04",
    },
    {
        "name": "retrieve_author05",
    },
    {
        "name": "retrieve_bench06",
    },
    {
        "name": "retrieve_verdict08",
    },
    {
        "name": "retirve_alldeets09",
    }
]



batch = {}

for intent in intents:
    intent_name = intent["name"]
    batch["name"] = intent_name
    requests.post(TRAINING_ENDPOINT, headers=headers, json=batch)

# %% [markdown]
# # CODE TO TRAIN (10)

# %%
import requests
import time
import random
import json

# Define your Wit.ai access token and app ID
WITAI_ACCESS_TOKEN = 'MWLBURSN7OWE4F2ANHQ2P7L7QZVNJ6DH'
WITAI_APP_ID = '1063283911477629'

# Define the Wit.ai API endpoint for training
TRAINING_ENDPOINT = 'https://api.wit.ai/utterances?v=20230215'

# Define entity values
entities = {
   "Author": [
        "A Patel", "I Verma", "R Singh", "A Sharma", "D Gupta",
        "S Kapoor", "A Yadav", "L Krishnan", "V Agarwal", "J Sharma"
    ],
    "Statute": [
        "IPC Section 302", "CRPC Section 100", "CPC Section 210", "Evidence Act", "Company Law",
        "Contract Act", "Sales Tax Act", "Income Tax Act", "Customs Act", "Patents Act"
    ],
    "Case_type": [
        "fraud", "theft", "robbery", "cybercrime", "murder",
        "assault", "contract dispute", "tax evasion", "patent infringement", "consumer protection"
    ],
    "wit$datetime": [
        "16 May, 2023", "15 June, 2021", "27 October, 2022", "31 December, 2023", "22 August, 2024",
        "19 March, 2025", "30 November, 2025", "14 July, 2026", "25 September, 2026", "08 January, 2027"
    ],
    "Bench": [
        "J Patel, A Verma", "L Krishnan, J Patel, D Gupta", "M Brown, D Wilson, S Davis", "R Singh, W Agarwal",
        "C Sharma, A Yadav, P Krishnan", "E Krishnan, M Gupta", "B Sharma, L Yadav", "K Brown, J Agarwal", "D Gupta, S Sharma", "P Krishnan, M Yadav"
    ],
   "Case_name": [
        "The People vs. Aarav Patel", "State of Maharashtra vs. Jio Ltd", "Krishnan & Sons vs. Wilson Enterprises",
        "Verma vs. Brown and Yadav", "Agarwal vs. The Commissioner of Taxation"
    ],
    "Verdict": [
        "The appeal is allowed, and the order passed by the High Court is set aside", "Supreme Court appeals dismissed",
        "Verdict in favor of the plaintiff", "The defendant is found guilty of patent infringement", "Tax evasion charges dropped due to lack of evidence"
    ],
    "Precedent": [
        "2005 AIR 1245", "2010 SCR 567", "AIR 2012 SC 890", "(2014) 6 SCC 321", "2020 (2) UJ 456 SC",
        "1988 AIR 789", "1995 SCR 234", "AIR 2000 SC 123", "(2002) 3 SCC 567", "2018 (4) UJ 789 SC"
    ],
}

# Define intents and example phrases with specific entity values
intents = [
    {
        "name": "retrieve_case01",
        "examples": [
            "Find cases citing {Precedent} where {Verdict}",
            "Show cases with {Statute}",
            "Retrieve cases citing {Precedent} with {Statute} where {Verdict}",
            "Search cases based on {Statute} citing {Precedent} by {Author}",
            "Fetch cases by {Author}",
            "Show cases with {Bench}",
            "Retrieve cases of {Case_type} on {wit/datetime}",
            "Find case {Case_name}",
            "Search cases based on {wit/datetime} by {Author} citing {Precedent}",
            "Get cases by {Auhtor} of {Case_type}"
        ],
        "name": "retrieve_statute03",
        "examples": [
            "Find statutes where {Verdict}",
            "Show statutes citing {Precedent}",
            "Retrieve statutes where {Verdict} citing {Precedent}",
            "Search statutes citing {Precedent} by {Author}",
            "Fetch statutes involving {Author}",
            "Show statutes with {Bench}",
            "Retrieve statutes of {Case_type} on {wit/datetime}",
            "Find statutes of {Case_name}",
            "Search statutes based on {wit/datetime} by {Author} citing {Precedent}",
            "Get statutes by {Auhtor} of {Case_type}"
        ],
        "name": "retrieve_date04",
        "examples": [
           "Find date citing {Precedent} where {Verdict}",
            "Show date with {Statute}",
            "Retrieve date citing {Precedent} and where {Verdict} with {Statute}",
            "Search date with {Statute} citing {Precedent} by {Author}",
            "Fetch date by {Author}",
            "Show date with {Bench}",
            "Retrieve date of {Case_type} where {Verdict}",
            "Find date {Case_name}",
            "Search date based on {wit/datetime} by {Author} citing {Precedent}",
            "Get date by {Auhtor} of {Case_type}"
        ],
        "name": "retrieve_author05",
        "examples": [
            "Find author citing {Precedent} where {Verdict}",
            "Show author of case with {Statute}",
            "Retrieve author of case following {Precedent} and where {Verdict} with {Statute}",
            "Search author of case based on {Statute} citing {Precedent} by {Author}",
            "Show author of case with {Bench}",
            "Get author with {Bench} with {Statute}"
            "Retrieve author of case of {Case_type} on {wit/datetime}",
            "Find author of case {Case_name}",
            "Search author based on {wit/datetime} by {Bench} citing {Precedent}",
            "Get author by {Auhtor} of {Case_type}"
        ],
        "name": "retrieve_bench06",
        "examples": [
            "Find bench citing {Precedent} with {Verdict}",
            "Show bench with {Statute}",
            "Retrieve bench following {Precedent} and having {Verdict} with {Statute}",
            "Search bench based on {Statute} citing {Precedent} by {Author}",
            "Fetch bench by {Author}",
            "Get bench by {Auhtor} with {Statute}"
            "Retrieve bench of {Case_type} on {wit/datetime}",
            "Find bench {Case_name}",
            "Search bench based on {wit/datetime} by {Author} citing {Precedent}",
            "Get bench by {Auhtor} of {Case_type}"
        ],
        "name": "retrieve_verdict08",
        "examples": [
            "Find verdict citing {Precedent}",
            "Show verdict with {Statute}",
            "Retrieve verdict following {Precedent} and having {Verdict} with {Statute}",
            "Search verdict based on {Statute} citing {Precedent} by {Author}",
            "Fetch verdict by {Author}",
            "Show verdict with {Bench}",
            "Retrieve verdict of {Case_type} on {wit/datetime}",
            "Find verdict {Case_name}",
            "Search verdict based on {wit/datetime} by {Author} citing {Precedent}",
            "Get verdict by {Auhtor} of {Case_type}"
        ]
    }
]


for intent in intents:
    for example in intent["examples"]:
        intent["examples"] = [example.replace("wit/datetime", "wit$datetime") for example in intent["examples"]]

# Function to generate utterance data
def generate_utterance_data(intent_examples, entity_values):
    utterance_data = []

    for intent in intent_examples:
        intent_name = intent["name"]
        for example in intent["examples"]:
            entities = []  # Initialize entities list for this example
            text = example  # Initialize the text with the example

            # Iterate through entities to find the ones mentioned in the example
            for entity_name in entity_values:
                if "{" + entity_name + "}" in text:
                    # Select a random value from the entity's values
                    selected_value = random.choice(entity_values[entity_name])
                    text = text.replace("{" + entity_name + "}", selected_value)
                    # Find the starting position of the entity within the text
                    start = text.find(selected_value)
                    if start >= 0:
                        end = start + len(selected_value) - 1
                        if entity_name == "wit$datetime":
                           entities.append({
                                "entity": f"{entity_name}:datetime",
                                "start": start,
                                "end": end,
                                "body": selected_value,
                                "entities": []
                            })
                        else:
                            entities.append({
                                "entity": f"{entity_name}:{entity_name}",
                                "start": start,
                                "end": end,
                                "body": selected_value,
                                "entities": []
                            })


            if entities:  # Only add the utterance if entities are present
                utterance = {
                    "text": text,
                    "intent": intent_name,
                    "entities": entities,
                    "traits": []  # Replace with traits if needed
                }
                utterance_data.append(utterance)

    return utterance_data


def train_wit_ai(utterance_data, batch_size=50):
    headers = {
        'Authorization': f'Bearer {WITAI_ACCESS_TOKEN}',
        'Content-Type': 'application/json',
    }

    # Split the utterance data into batches
    for i in range(0, len(utterance_data), batch_size):
        batch = utterance_data[i:i + batch_size]

        # Send a POST request to train Wit.ai for each batch
        response = requests.post(TRAINING_ENDPOINT, headers=headers, json=batch)
        response_json = response.json()

        if "error" in response_json:
            print("Training failed for batch. Error message:", response_json["error"])
        else:
            print("Training successful for batch.")

        # Sleep for a few seconds to avoid rate limits
        time.sleep(5)

# Generate utterance data and train Wit.ai in batches
utterance_data = generate_utterance_data(intents, entities)
train_wit_ai(utterance_data, batch_size=50)
# Out:
# Training successful for batch.

# %% [markdown]
# # CODE TO TRAIN (20)

# %%
import requests
import time
import random
import json

# Define your Wit.ai access token and app ID
WITAI_ACCESS_TOKEN = 'MWLBURSN7OWE4F2ANHQ2P7L7QZVNJ6DH'
WITAI_APP_ID = '1063283911477629'

# Define the Wit.ai API endpoint for training
TRAINING_ENDPOINT = 'https://api.wit.ai/utterances?v=20230215'

# Define entity values
entities = {
   "Author": [
        "A Patel", "I Verma", "R Singh", "A Sharma", "D Gupta",
        "S Kapoor", "A Yadav", "L Krishnan", "V Agarwal", "J Sharma"
    ],
    "Statute": [
        "IPC Section 302", "CRPC Section 100", "CPC Section 210", "Evidence Act", "Company Law",
        "Contract Act", "Sales Tax Act", "Income Tax Act", "Customs Act", "Patents Act"
    ],
    "Case_type": [
        "fraud", "theft", "robbery", "cybercrime", "murder",
        "assault", "contract dispute", "tax evasion", "patent infringement", "consumer protection"
    ],
    "wit$datetime": [
        "16 May, 2023", "15 June, 2021", "27 October, 2022", "31 December, 2023", "22 August, 2024",
        "19 March, 2025", "30 November, 2025", "14 July, 2026", "25 September, 2026", "08 January, 2027"
    ],
    "Bench": [
        "J Patel, A Verma", "L Krishnan, J Patel, D Gupta", "M Brown, D Wilson, S Davis", "R Singh, W Agarwal",
        "C Sharma, A Yadav, P Krishnan", "E Krishnan, M Gupta", "B Sharma, L Yadav", "K Brown, J Agarwal", "D Gupta, S Sharma", "P Krishnan, M Yadav"
    ],
   "Case_name": [
        "The People vs. Aarav Patel", "State of Maharashtra vs. Jio Ltd", "Krishnan & Sons vs. Wilson Enterprises",
        "Verma vs. Brown and Yadav", "Agarwal vs. The Commissioner of Taxation"
    ],
    "Verdict": [
        "The appeal is allowed, and the order passed by the High Court is set aside", "Supreme Court appeals dismissed",
        "Verdict in favor of the plaintiff", "The defendant is found guilty of patent infringement", "Tax evasion charges dropped due to lack of evidence"
    ],
    "Precedent": [
        "2005 AIR 1245", "2010 SCR 567", "AIR 2012 SC 890", "(2014) 6 SCC 321", "2020 (2) UJ 456 SC",
        "1988 AIR 789", "1995 SCR 234", "AIR 2000 SC 123", "(2002) 3 SCC 567", "2018 (4) UJ 789 SC"
    ],
}

# Define intents and example phrases with specific entity values
intents = [
    {
        "name": "retrieve_case01",
        "examples": [
            "Find cases citing {Precedent} where {Verdict}",
            "Show cases with {Statute}",
            "Retrieve cases citing {Precedent} with {Statute} where {Verdict}",
            "Search cases based on {Statute} citing {Precedent} by {Author}",
            "Fetch cases by {Author}",
            "Show cases with {Bench}",
            "Retrieve cases of {Case_type} on {wit/datetime}",
            "Find case {Case_name}",
            "Search cases based on {wit/datetime} by {Author} citing {Precedent}",
            "Get cases by {Author} of {Case_type}"
        ],
    },
    {
        "name": "retrieve_statute03",
        "examples": [
            "Find statutes where {Verdict}",
            "Show statutes citing {Precedent}",
            "Retrieve statutes where {Verdict} citing {Precedent}",
            "Search statutes citing {Precedent} by {Author}",
            "Fetch statutes involving {Author}",
            "Show statutes with {Bench}",
            "Retrieve statutes of {Case_type} on {wit/datetime}",
            "Find statutes of {Case_name}",
            "Search statutes based on {wit/datetime} by {Author} citing {Precedent}",
            "Get statutes by {Author} of {Case_type}"
        ],
    },
    {
        "name": "retrieve_date04",
        "examples": [
           "Find date citing {Precedent} where {Verdict}",
            "Show date with {Statute}",
            "Retrieve date citing {Precedent} and where {Verdict} with {Statute}",
            "Search date with {Statute} citing {Precedent} by {Author}",
            "Fetch date by {Author}",
            "Show date with {Bench}",
            "Retrieve date of {Case_type} where {Verdict}",
            "Find date {Case_name}",
            "Search date based on {wit/datetime} by {Author} citing {Precedent}",
            "Get date by {Author} of {Case_type}"
        ],
    },
    {
        "name": "retrieve_author05",
        "examples": [
            "Find author citing {Precedent} where {Verdict}",
            "Show author of case with {Statute}",
            "Retrieve author of case following {Precedent} and where {Verdict} with {Statute}",
            "Search author of case based on {Statute} citing {Precedent} by {Author}",
            "Show author of case with {Bench}",
            "Get author with {Bench} with {Statute}"
            "Retrieve author of case of {Case_type} on {wit/datetime}",
            "Find author of case {Case_name}",
            "Search author based on {wit/datetime} by {Bench} citing {Precedent}",
            "Get author by {Author} of {Case_type}"
        ],
    },
    {
        "name": "retrieve_bench06",
        "examples": [
            "Find bench citing {Precedent} with {Verdict}",
            "Show bench with {Statute}",
            "Retrieve bench following {Precedent} and having {Verdict} with {Statute}",
            "Search bench based on {Statute} citing {Precedent} by {Author}",
            "Fetch bench by {Author}",
            "Get bench by {Author} with {Statute}"
            "Retrieve bench of {Case_type} on {wit/datetime}",
            "Find bench {Case_name}",
            "Search bench based on {wit/datetime} by {Author} citing {Precedent}",
            "Get bench by {Author} of {Case_type}"
        ],
    },
    {
        "name": "retrieve_verdict08",
        "examples": [
            "Find verdict citing {Precedent}",
            "Show verdict with {Statute}",
            "Retrieve verdict following {Precedent} and having {Verdict} with {Statute}",
            "Search verdict based on {Statute} citing {Precedent} by {Author}",
            "Fetch verdict by {Author}",
            "Show verdict with {Bench}",
            "Retrieve verdict of {Case_type} on {wit/datetime}",
            "Find verdict {Case_name}",
            "Search verdict based on {wit/datetime} by {Author} citing {Precedent}",
            "Get verdict by {Author} of {Case_type}"
        ]
    },
    {
        "name":"retrieve_alldeets10",
        "examples": [
            "Fetch details of case by {Author}"
            "Show all details of case with {Statute}"
            "Retrieve all details following {Precedent} and having {Verdict} with {Statute}",
            "Search all details based on {Statute} citing {Precedent} by {Author}",
            "Fetch all details by {Author}",
            "Show all details with {Bench}",
            "Retrieve all details of {Case_type} on {wit/datetime}",
            "Find all details {Case_name}",
            "Search all details based on {wit/datetime} by {Author} citing {Precedent}",
            "Get all details by {Author} of {Case_type}"
        ]
    }
]


for intent in intents:
    for example in intent["examples"]:
        intent["examples"] = [example.replace("wit/datetime", "wit$datetime") for example in intent["examples"]]

# Function to generate utterance data
def generate_utterance_data(intent_examples, entity_values):
    utterance_data = []

    for intent in intent_examples:
        intent_name = intent["name"]
        for example in intent["examples"]:
            entities = []  # Initialize entities list for this example
            text = example  # Initialize the text with the example

            # Iterate through entities to find the ones mentioned in the example
            for entity_name in entity_values:
                if "{" + entity_name + "}" in text:
                    # Select a random value from the entity's values
                    selected_value = random.choice(entity_values[entity_name])
                    text = text.replace("{" + entity_name + "}", selected_value)
                    # Find the starting position of the entity within the text
                    start = text.find(selected_value)
                    if start >= 0:
                        end = start + len(selected_value) - 1
                        if entity_name == "wit$datetime":
                           entities.append({
                                "entity": f"{entity_name}:datetime",
                                "start": start,
                                "end": end,
                                "body": selected_value,
                                "entities": []
                            })
                        else:
                            entities.append({
                                "entity": f"{entity_name}:{entity_name}",
                                "start": start,
                                "end": end,
                                "body": selected_value,
                                "entities": []
                            })


            if entities:  # Only add the utterance if entities are present
                utterance = {
                    "text": text,
                    "intent": intent_name,
                    "entities": entities,
                    "traits": []  # Replace with traits if needed
                }
                utterance_data.append(utterance)

    return utterance_data


def train_wit_ai(utterance_data, batch_size=50):
    headers = {
        'Authorization': f'Bearer {WITAI_ACCESS_TOKEN}',
        'Content-Type': 'application/json',
    }

    # Split the utterance data into batches
    for i in range(0, len(utterance_data), batch_size):
        batch = utterance_data[i:i + batch_size]

        # Send a POST request to train Wit.ai for each batch
        response = requests.post(TRAINING_ENDPOINT, headers=headers, json=batch)
        response_json = response.json()

        if "error" in response_json:
            print("Training failed for batch. Error message:", response_json["error"])
        else:
            print("Training successful for batch.")

        # Sleep for a few seconds to avoid rate limits
        time.sleep(5)

# Generate utterance data and train Wit.ai in batches
utterance_data = generate_utterance_data(intents, entities)
train_wit_ai(utterance_data, batch_size=50)
# Out:
# Training failed for batch. Error message: Failed to validate utterance at index 0. Could not find entity "Precedent:Precedent".
# Training failed for batch. Error message: Failed to validate utterance at index 0. Could not find entity "Precedent:Precedent".

# %% [markdown]
# # CODE TO TEST

# %%
# !pip install wit
# !pip install scikit-learn
# !pip install rouge
# Out:
# Collecting wit
#   Downloading wit-6.0.1.tar.gz (6.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.10/dist-packages (from wit) (3.0.43)
# Requirement already satisfied: requests>=0.8.8 in /usr/local/lib/python3.10/dist-packages (from wit) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=0.8.8->wit) (2024.2.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt_toolkit->wit) (0.2.13)
# Building wheels for collected packages: wit
#   Building wheel for wit (setup.py) ... done
#   Created wheel for wit: filename=wit-6.0.1-py3-none-any.whl size=5297 sha256=9df8d245507ee31f1d518d00f7700675f9854697879fb36581c6bc534f97bd40
#   Stored in directory: /root/.cache/pip/wheels/a9/ea/7d/55ba15bb7612a6adea29f8085ad022e657c0ec8ba6ec6e7fc4
# Successfully built wit
# Installing collected packages: wit
# Successfully installed wit-6.0.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.3.0)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
from wit import Wit
from sklearn.metrics import precision_score, recall_score, f1_score
from rouge import Rouge
from sklearn.metrics import precision_recall_fscore_support

# Replace with your Wit.ai access token
ACCESS_TOKEN = "MWLBURSN7OWE4F2ANHQ2P7L7QZVNJ6DH"

# Initialize the Wit.ai client
client = Wit(access_token=ACCESS_TOKEN)


test_data = [
    {"question": "Find cases by R Sharma", "intent": "retrieve_case01", "entities": {"Author": ["R Sharma"]}},
    {"question": "Show cases with M Patel", "intent": "retrieve_case01", "entities": {"Author": ["M Patel"]}},
    {"question": "Retrieve cases on 23 july, 2002 with IPC Section 132", "intent": "retrieve_case01", "entities": {"Statute": ["IPC Section 132"], "wit$datetime": ["on 23 july, 2002"] }},
    {"question": "Search cases with A Verma, M Prasad where sentence is upheld", "intent": "retrieve_case01", "entities": {"Bench": ["A Verma, M Prasad"], "Verdict": ["sentence is upheld"]}},
    {"question": "Cases by L Yadav", "intent": "retrieve_case01", "entities": {"Author": ["L Yadav"]}},

    {"question": "Find statutes where Appeal dismissed", "intent": "retrieve_statute03", "entities": {"Verdict": ["Appeal dismissed"]}},
    {"question": "Show statutes on 19 June, 2001", "intent": "retrieve_statute03", "entities": {"wit$datetime": ["on 19 June, 2001"]}},
    {"question": "Retrieve statute of case by M Patel", "intent": "retrieve_statute03", "entities": {"Author": ["M Patel"]}},
    {"question": "Search statute by S Patel on 23 march, 2001", "intent": "retrieve_statute03", "entities": {"Author": ["S Patel"], "wit$datetime": ["on 23 march, 2001"]}},
    {"question": "Fetch statutes by S Patel", "intent": "retrieve_statute03", "entities": {"Author": ["S Patel"]}},

    {"question": "Find date where Appeal dismissed", "intent": "retrieve_date04", "entities": {"Verdict": ["Appeal dismissed"]}},
    {"question": "Show date with IPC Section 119", "intent": "retrieve_date04", "entities": {"Statute": ["IPC Section 119"]}},
    {"question": "Retrieve date where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_date04", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["The order passed by the High Court is set aside"]}},
    {"question": "Search date with Patents Act by M Brown", "intent": "retrieve_date04", "entities": {"Author": ["M Brown"], "Statute": ["Patents Act"]}},
    {"question": "Fetch date by J Martin", "intent": "retrieve_date04", "entities": {"Author": ["J Martin"]}},
    {"question": "Show date with B Smith, L Wilson", "intent": "retrieve_date04", "entities": {"Bench": ["B Smith, L Wilson"]}},
    {"question": "Retrieve date where The appeal is allowed and the order passed by the High Court is set aside", "intent": "retrieve_date04", "entities": {"Verdict": ["The appeal is allowed and The order passed by the High Court is set aside"]}},
    {"question": "Find date The People vs. John Smith", "intent": "retrieve_date04", "entities": {"Case_Name": ["The People vs. John Smith"]}},

    {"question": "Find author where Appeal dismissed with IPC Section 30", "intent": "retrieve_author05", "entities": {"Statute": ["IPC Section 30"], "Verdict": ["Appeal dismissed"]}},
    {"question": "Show author of case with IPC Section 119", "intent": "retrieve_author05", "entities": {"Statute": ["IPC Section 119"]}},
    {"question": "Retrieve author of case where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_author05", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["The order passed by the High Court is set aside"]}},
    {"question": "Search author of case based on Patents Act by M Brown", "intent": "retrieve_author05", "entities": {"Author": ["M Brown"], "Statute": ["Patents Act"]}},
    {"question": "Show author of case with B Smith, L Wilson", "intent": "retrieve_author05", "entities": {"Bench": ["B Smith", "L Wilson"]}},
    {"question": "Retrieve author of case on 25 September, 2026", "intent": "retrieve_author05", "entities": {"wit$datetime": ["on 25 September, 2026"]}},
    {"question": "Find author of case The People vs. John Smith", "intent": "retrieve_author05", "entities": {"Case_Name": ["The People vs. John Smith"]}},

    {"question": "Find bench where Appeal dismissed", "intent": "retrieve_bench06", "entities": {"Verdict": ["Appeal dismissed"]}},
    {"question": "Show bench with IPC Section 119", "intent": "retrieve_bench06", "entities": {"Statute": ["IPC Section 119"]}},
    {"question": "Retrieve bench where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_bench06", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["The order passed by the High Court is set aside"]}},
    {"question": "Search bench based on Patents Act by M Brown", "intent": "retrieve_bench06", "entities": {"Author": ["M Brown"], "Statute": ["Patents Act"]}},
    {"question": "Fetch bench by J Martin", "intent": "retrieve_bench06", "entities": {"Author": ["J Martin"]}},
    {"question": "Retrieve bench on 25 September, 2026", "intent": "retrieve_bench06", "entities": {"wit$datetime": ["on 25 September, 2026"]}},
    {"question": "Find bench The People vs. John Smith", "intent": "retrieve_bench06", "entities": {"Case_Name": ["The People vs. John Smith"]}},

    {"question": "Find verdict by N Modi", "intent": "retrieve_verdict08", "entities": {"Author": ["N Modi"]}},
    {"question": "Show verdict with IPC Section 119", "intent": "retrieve_verdict08", "entities": {"Statute": ["IPC Section 119"]}},
    {"question": "Retrieve verdict following where Appeal dismissed with Income Tax Act", "intent": "retrieve_verdict08", "entities": {"Verdict": ["Appeal dismissed"], "Statute": ["Income Tax Act"]}},
    {"question": "Search verdict based on Patents Act by M Brown", "intent": "retrieve_verdict08", "entities": {"Author": ["M Brown"], "Statute": ["Patents Act"]}},
    {"question": "Fetch verdict by J Martin", "intent": "retrieve_verdict08", "entities": {"Author": ["J Martin"]}},
    {"question": "Show verdict with B Smith, L Wilson", "intent": "retrieve_verdict08", "entities": {"Author": ["B Smith", "L Wilson"]}},
    {"question": "Retrieve verdict on 25 September, 2026", "intent": "retrieve_verdict08", "entities": {"wit$datetime": ["on 25 September, 2026"]}},
    {"question": "Find verdict The People vs. John Smith", "intent": "retrieve_verdict08", "entities": {"Case_Name": ["The People vs. John Smith"]}},
]


# Define your test data with expected entities
test_data += [
    {"question": "Find cases with S Sharma and K Patel", "intent": "retrieve_case01", "entities": {"Author": ["S Sharma", "K Patel"]}},
    {"question": "Show cases with K Patel with IPC Section 13", "intent": "retrieve_case01", "entities": {"Author": ["K Patel"], "Statute": ["IPC Section 13"]}},
    {"question": "Retrieve cases with IPC Section 13 on 15th August, 2003", "intent": "retrieve_case01", "entities": {"Statute": ["IPC Section 13"], "wit$datetime": ["on 15th August, 2003"]}},
    {"question": "Search cases with P Verma, Q Prasad and N Patel on 20th March, 2002", "intent": "retrieve_case01", "entities": {"Bench": ["P Verma, Q Prasad and N Patel"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Cases by M Yadav with IPC Section 30", "intent": "retrieve_case01", "entities": {"Author": ["M Yadav"], "Statute": ["IPC Section 30"]}},

    {"question": "Find statutes where Sentence upheld", "intent": "retrieve_statute03", "entities": {"Verdict": ["Sentence upheld"]}},
    {"question": "Show statutes by S Patel on 15 July, 2001", "intent": "retrieve_statute03", "entities": {"Author": ["S Patel"], "wit$datetime": ["on 15 July, 2001"]}},
    {"question": "Retrieve statute of case by S Patel on 20th March, 2002", "intent": "retrieve_statute03", "entities": {"Author": ["S Patel"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Search statute by N Patel on 20th March, 2002", "intent": "retrieve_statute03", "entities": {"Author": ["N Patel"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Fetch statutes where sentence is upheld on 19 March, 2001", "intent": "retrieve_statute03", "entities": {"Verdict": ["sentence is upheld"], "wit$datetime": ["on 19 March, 2001"]}},

    {"question": "Find date where Sentence upheld with CrPC Section 136", "intent": "retrieve_date04", "entities": {"Statute": ["CrPC Section 136"],"Verdict": ["Sentence upheld"]}},
    {"question": "Show date with by P Brown IPC Section 136 and Evidence Act", "intent": "retrieve_date04", "entities": {"Author": ["P Brown"], "Statute": ["IPC Section 136", "Evidence Act"]}},
    {"question": "Retrieve date where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_date04", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["The order passed by the High Court is set aside"]}},
    {"question": "Search date with Evidence Act by P Brown and Q Patel", "intent": "retrieve_date04", "entities": {"Bench": ["P Brown and Q Patel"], "Statute": ["Evidence Act"]}},
    {"question": "Fetch date by Q Patel, M Wilson, L Davis", "intent": "retrieve_date04", "entities": {"Bench": ["Q Patel", "M Wilson, L Davis"]}},
    {"question": "Show date with K Brown, L Wilson where The sentence is commuted", "intent": "retrieve_date04", "entities": {"Bench": ["K Brown, L Wilson"], "Verdict": ["The sentence is commuted"]}},
    {"question": "Retrieve date where The appeal is dismissed", "intent": "retrieve_date04", "entities": {"Verdict": ["The appeal is dismissed"]}},
    {"question": "Find date The State vs. John Doe with IPC Section 13", "intent": "retrieve_date04", "entities": {"Case_Name": ["The State vs. John Doe"], "Statute": ["IPC Section 13"]}},

    {"question": "Find author where Sentence upheld with CrPC Section 136", "intent": "retrieve_author05", "entities": {"Verdict": ["Sentence upheld"], "Statute": ["CrPC Section 136"]}},
    {"question": "Show author of case by P Brown with IPC Section 136 and Evidence Act", "intent": "retrieve_author05", "entities": {"Author": ["P Brown"], "Statute": ["IPC Section 136", "Evidence Act"]}},
    {"question": "Retrieve author of case where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_author05", "entities": {"Verdict": ["The order passed by the High Court is set aside"], "Statute": ["Income Tax Act"]}},
    {"question": "Search author of case based on Evidence Act", "intent": "retrieve_author05", "entities": {"Statute": ["Evidence Act"]}},
    {"question": "Show author of case with K Brown, L Wilson and IPC Section 136", "intent": "retrieve_author05", "entities": {"Bench": ["K Brown", "L Wilson"], "Statute": ["IPC Section 136"]}},
    {"question": "Retrieve author of case on 20th March, 2002 with IPC Section 13", "intent": "retrieve_author05", "entities": { "Statute": ["IPC Section 13"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Find author of case The State vs. John Doe with IPC Section 13", "intent": "retrieve_author05", "entities": {"Case_Name": ["The State vs. John Doe"], "Statute": ["IPC Section 13"]}},

    {"question": "Find bench with Sentence upheld and CrPC Section 136", "intent": "retrieve_bench06", "entities": {"Verdict": ["Sentence upheld"], "Statute": ["CrPC Section 136"]}},
    {"question": "Show bench with IPC Section 136 and Evidence Act", "intent": "retrieve_bench06", "entities": {"Statute": ["IPC Section 136", "Evidence Act"]}},
    {"question": "Retrieve bench where The order passed by the High Court is set aside with Income Tax Act", "intent": "retrieve_bench06", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["The order passed by the High Court is set aside"]}},
    {"question": "Search bench based on Evidence Act by P Brown and Q Patel", "intent": "retrieve_bench06", "entities": {"Bench": ["P Brown", "Q Patel"], "Statute": ["Evidence Act"]}},
    {"question": "Fetch bench by Q Patel and M Wilson, L Davis", "intent": "retrieve_bench06", "entities": {"Bench": ["Q Patel", "M Wilson", "L Davis"]}},
    {"question": "Retrieve bench on 20th March, 2002 with IPC Section 13", "intent": "retrieve_bench06", "entities": {"Statute": ["IPC Section 13"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Find bench The State vs. John Doe with IPC Section 13", "intent": "retrieve_bench06", "entities": {"Case_Name": ["The State vs. John Doe"], "Statute": ["IPC Section 13"]}},

    {"question": "Find verdict with IPC Section 136", "intent": "retrieve_verdict08", "entities": {"Statute": ["IPC Section 136"]}},
    {"question": "Show verdict with IPC Section 136 by P Brown", "intent": "retrieve_verdict08", "entities": {"Statute": ["IPC Section 136"], "Author": ["P Brown"]}},
    {"question": "Retrieve verdict where Sentence upheld with Income Tax Act", "intent": "retrieve_verdict08", "entities": {"Statute": ["Income Tax Act"], "Verdict": ["Sentence upheld"]}},
    {"question": "Search verdict based on Evidence Act by P Brown and Q Patel", "intent": "retrieve_verdict08", "entities": {"Bench": ["P Brown and Q Patel"], "Statute": ["Evidence Act"]}},
    {"question": "Fetch verdict by Q Patel and M Wilson, L Davis", "intent": "retrieve_verdict08", "entities": {"Bench": ["Q Patel and M Wilson, L Davis"]}},
    {"question": "Show verdict with K Brown, L Wilson with IPC Section 136", "intent": "retrieve_verdict08", "entities": {"Bench": ["K Brown, L Wilson"], "Statute": ["IPC Section 136"]}},
    {"question": "Retrieve verdict on 20th March, 2002 with IPC Section 13", "intent": "retrieve_verdict08", "entities": {"Statute": ["IPC Section 13"], "wit$datetime": ["on 20th March, 2002"]}},
    {"question": "Find verdict The State vs. John Doe with IPC Section 13", "intent": "retrieve_verdict08", "entities": {"Case_Name": ["The State vs. John Doe"], "Statute": ["IPC Section 13"]}},
]


# Initialize variables to keep track of metrics
total_questions = len(test_data)
correct_intent_predictions = 0
correct_entity_predictions = 0

# Lists to store true and predicted labels for calculating precision, recall, and F-measure
true_intent_labels = []
predicted_intent_labels = []

# Lists to store true and predicted summaries for calculating ROUGE scores
true_summaries = []
predicted_summaries = []

entity_values_list = []

true_entities_set = []
predicted_entities_set = []

# Loop through the test questions
for data in test_data:
    expected_intent = data["intent"]
    true_intent_labels.append(expected_intent)

    # Send the test question to Wit.ai for intent detection
    response = client.message(data["question"])

    expected_entities = data.get("entities", {})

    entity_values = {}
    for entity_type, entity_list in response["entities"].items():
        if isinstance(entity_list, list) and entity_list:
            # Remove extra ':' and concatenate values for the same entity type
            cleaned_entity_type = entity_type.split(':')[0]
            entity_values[cleaned_entity_type] = [entity['body'] for entity in entity_list]


    predicted_intent = response["intents"][0]["name"] if response["intents"] else None
    # Replace None with an empty string
    predicted_intent = predicted_intent if predicted_intent is not None else ""
    predicted_intent_labels.append(predicted_intent)

    true_entities_set.append(expected_entities)

    entity_values = entity_values if entity_values is not None else "Dummy"
    predicted_entities_set.append(entity_values)

    # For ROUGE scores, extract summaries
    true_summaries.append(data["intent"].replace('_', ' '))

    # Check if predicted_intent is not None before replacing underscores
    if predicted_intent != "":
        predicted_summaries.append(predicted_intent.replace('_', ' '))

        if predicted_intent == expected_intent:
          correct_intent_predictions += 1
    else:
        predicted_summaries.append("retirve case02")

    if entity_values == expected_entities:
        correct_entity_predictions += 1

# # Calculate precision, recall, and F-measure
# for i, entity_values in enumerate(entity_values_list):
#     print(f"Question {i + 1} - Extracted Entity Values:")
#     for entity_type, values in entity_values.items():
#         print(f"{entity_type} Values: {values}")


# Calculate precision, recall, and F-measure for intents
precision_intent = precision_score(true_intent_labels, predicted_intent_labels, average='micro', zero_division=1)
recall_intent = recall_score(true_intent_labels, predicted_intent_labels, average='weighted', zero_division=1)
f1_intent = f1_score(true_intent_labels, predicted_intent_labels, average='weighted', zero_division=1)

# # Assuming both lists have the same length
# for true_entity, predicted_entity in zip(true_intent_labels, predicted_intent_labels):
#     print("True intent:", true_intent_labels)
#     print("Predicted intent:", predicted_intent_labels)


# Assuming both lists have the same length
for true_entity, predicted_entity in zip(true_entities_set, predicted_entities_set):
    print("True Entity:", true_entity)
    print("Predicted Entity:", predicted_entity)


true_entities_set = [str(entity) for entity in true_entities_set]
predicted_entities_set = [str(entity) for entity in predicted_entities_set]

# Calculate precision, recall, and F-measure for entities
precision_entity = precision_score(true_entities_set, predicted_entities_set, average='macro', zero_division=1)
recall_entity = recall_score(true_entities_set, predicted_entities_set, average='micro', zero_division=1)
f1_entity = f1_score(true_entities_set, predicted_entities_set, average='micro', zero_division=1)


# Print results for intents
print("Intent Metrics:")
print(f"\nAccuracy: {correct_intent_predictions / total_questions:.2%}")
print(f"Precision: {precision_intent:.2%}")
print(f"Recall: {recall_intent:.2%}")
print(f"F-measure: {f1_intent:.2%}")


# Print results for entities
print("\nEntity Metrics:")
print(f"\nAccuracy: {correct_entity_predictions / total_questions:.2%}")
print(f"Precision: {precision_entity:.2%}")
print(f"Recall: {recall_entity:.2%}")
print(f"F-measure: {f1_entity:.2%}")
# Out:
# True Entity: {'Author': ['R Sharma']}
# Predicted Entity: {'Author': ['R Sharma']}
# True Entity: {'Author': ['M Patel']}
# Predicted Entity: {'Author': ['M Patel']}
# True Entity: {'Statute': ['IPC Section 132'], 'wit$datetime': ['on 23 july, 2002']}
# Predicted Entity: {'Statute': ['IPC Section 132'], 'wit$datetime': ['on 23 july, 2002']}
# True Entity: {'Bench': ['A Verma, M Prasad'], 'Verdict': ['sentence is upheld']}
# Predicted Entity: {'Bench': ['A Verma, M Prasad where sentence is upheld']}
# True Entity: {'Author': ['L Yadav']}
# Predicted Entity: {'Author': ['L Yadav']}
# True Entity: {'Verdict': ['Appeal dismissed']}
# Predicted Entity: {'Verdict': ['Appeal dismissed']}
# True Entity: {'wit$datetime': ['on 19 June, 2001']}
# Predicted Entity: {'wit$datetime': ['on 19 June, 2001']}
# True Entity: {'Author': ['M Patel']}
# Predicted Entity: {'Author': ['M Patel']}
# True Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 23 march, 2001']}
# Predicted Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 23 march, 2001']}
# True Entity: {'Author': ['S Patel']}
# Predicted Entity: {'Author': ['S Patel']}
# True Entity: {'Verdict': ['Appeal dismissed']}
# Predicted Entity: {'Verdict': ['Appeal dismissed']}
# True Entity: {'Statute': ['IPC Section 119']}
# Predicted Entity: {'Statute': ['IPC Section 119']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# Predicted Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# True Entity: {'Author': ['J Martin']}
# Predicted Entity: {'Author': ['J Martin']}
# True Entity: {'Bench': ['B Smith, L Wilson']}
# Predicted Entity: {'Bench': ['B Smith, L Wilson']}
# True Entity: {'Verdict': ['The appeal is allowed and The order passed by the High Court is set aside']}
# Predicted Entity: {'Verdict': ['The appeal is allowed and the order passed by the High Court is set aside']}
# True Entity: {'Case_Name': ['The People vs. John Smith']}
# Predicted Entity: {'Case_Name': ['The People vs. John Smith']}
# True Entity: {'Statute': ['IPC Section 30'], 'Verdict': ['Appeal dismissed']}
# Predicted Entity: {'Statute': ['IPC Section 30'], 'Verdict': ['Appeal dismissed']}
# True Entity: {'Statute': ['IPC Section 119']}
# Predicted Entity: {'Statute': ['IPC Section 119']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# Predicted Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# True Entity: {'Bench': ['B Smith', 'L Wilson']}
# Predicted Entity: {'Bench': ['B Smith, L Wilson']}
# True Entity: {'wit$datetime': ['on 25 September, 2026']}
# Predicted Entity: {'wit$datetime': ['on 25 September, 2026']}
# True Entity: {'Case_Name': ['The People vs. John Smith']}
# Predicted Entity: {'Case_Name': ['The People vs. John Smith']}
# True Entity: {'Verdict': ['Appeal dismissed']}
# Predicted Entity: {'Verdict': ['Appeal dismissed']}
# True Entity: {'Statute': ['IPC Section 119']}
# Predicted Entity: {'Statute': ['IPC Section 119']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# Predicted Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# True Entity: {'Author': ['J Martin']}
# Predicted Entity: {'Author': ['J Martin']}
# True Entity: {'wit$datetime': ['on 25 September, 2026']}
# Predicted Entity: {'wit$datetime': ['on 25 September, 2026']}
# True Entity: {'Case_Name': ['The People vs. John Smith']}
# Predicted Entity: {'Case_Name': ['The People vs. John Smith']}
# True Entity: {'Author': ['N Modi']}
# Predicted Entity: {'Author': ['N Modi']}
# True Entity: {'Statute': ['IPC Section 119']}
# Predicted Entity: {'Statute': ['IPC Section 119']}
# True Entity: {'Verdict': ['Appeal dismissed'], 'Statute': ['Income Tax Act']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['Appeal dismissed']}
# True Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# Predicted Entity: {'Author': ['M Brown'], 'Statute': ['Patents Act']}
# True Entity: {'Author': ['J Martin']}
# Predicted Entity: {'Author': ['J Martin']}
# True Entity: {'Author': ['B Smith', 'L Wilson']}
# Predicted Entity: {'Bench': ['B Smith, L Wilson']}
# True Entity: {'wit$datetime': ['on 25 September, 2026']}
# Predicted Entity: {'wit$datetime': ['on 25 September, 2026']}
# True Entity: {'Case_Name': ['The People vs. John Smith']}
# Predicted Entity: {'Case_Name': ['The People vs. John Smith']}
# True Entity: {'Author': ['S Sharma', 'K Patel']}
# Predicted Entity: {'Bench': ['S Sharma and K Patel']}
# True Entity: {'Author': ['K Patel'], 'Statute': ['IPC Section 13']}
# Predicted Entity: {'Bench': ['K Patel'], 'Statute': ['IPC Section 13']}
# True Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 15th August, 2003']}
# Predicted Entity: {'Statute': ['IPC Section 13 on 15th August, 2003']}
# True Entity: {'Bench': ['P Verma, Q Prasad and N Patel'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Bench': ['P Verma, Q Prasad and N Patel'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Author': ['M Yadav'], 'Statute': ['IPC Section 30']}
# Predicted Entity: {'Author': ['M Yadav'], 'Statute': ['IPC Section 30']}
# True Entity: {'Verdict': ['Sentence upheld']}
# Predicted Entity: {'Verdict': ['Sentence upheld']}
# True Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 15 July, 2001']}
# Predicted Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 15 July, 2001']}
# True Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Author': ['S Patel'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Author': ['N Patel'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Author': ['N Patel'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Verdict': ['sentence is upheld'], 'wit$datetime': ['on 19 March, 2001']}
# Predicted Entity: {'Verdict': ['is upheld on 19 March, 2001']}
# True Entity: {'Statute': ['CrPC Section 136'], 'Verdict': ['Sentence upheld']}
# Predicted Entity: {'Statute': ['CrPC Section 136'], 'Verdict': ['Sentence upheld']}
# True Entity: {'Author': ['P Brown'], 'Statute': ['IPC Section 136', 'Evidence Act']}
# Predicted Entity: {'Bench': ['P Brown'], 'Statute': ['IPC Section 136', 'Evidence Act']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Bench': ['P Brown and Q Patel'], 'Statute': ['Evidence Act']}
# Predicted Entity: {'Bench': ['P Brown and Q Patel'], 'Statute': ['Evidence Act']}
# True Entity: {'Bench': ['Q Patel', 'M Wilson, L Davis']}
# Predicted Entity: {'Bench': ['Q Patel, M Wilson, L Davis']}
# True Entity: {'Bench': ['K Brown, L Wilson'], 'Verdict': ['The sentence is commuted']}
# Predicted Entity: {'Bench': ['K Brown, L Wilson'], 'Case_Name': ['The sentence is commuted']}
# True Entity: {'Verdict': ['The appeal is dismissed']}
# Predicted Entity: {'Verdict': ['The appeal is dismissed']}
# True Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# Predicted Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# True Entity: {'Verdict': ['Sentence upheld'], 'Statute': ['CrPC Section 136']}
# Predicted Entity: {'Statute': ['CrPC Section 136'], 'Verdict': ['Sentence upheld']}
# True Entity: {'Author': ['P Brown'], 'Statute': ['IPC Section 136', 'Evidence Act']}
# Predicted Entity: {'Author': ['P Brown'], 'Statute': ['IPC Section 136', 'Evidence Act']}
# True Entity: {'Verdict': ['The order passed by the High Court is set aside'], 'Statute': ['Income Tax Act']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Statute': ['Evidence Act']}
# Predicted Entity: {'Statute': ['Evidence Act']}
# True Entity: {'Bench': ['K Brown', 'L Wilson'], 'Statute': ['IPC Section 136']}
# Predicted Entity: {'Bench': ['K Brown, L Wilson'], 'Statute': ['IPC Section 136']}
# True Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# Predicted Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# True Entity: {'Verdict': ['Sentence upheld'], 'Statute': ['CrPC Section 136']}
# Predicted Entity: {'Statute': ['CrPC Section 136'], 'Verdict': ['Sentence upheld']}
# True Entity: {'Statute': ['IPC Section 136', 'Evidence Act']}
# Predicted Entity: {'Statute': ['IPC Section 136', 'Evidence Act']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['The order passed by the High Court is set aside']}
# True Entity: {'Bench': ['P Brown', 'Q Patel'], 'Statute': ['Evidence Act']}
# Predicted Entity: {'Bench': ['P Brown and Q Patel'], 'Statute': ['Evidence Act']}
# True Entity: {'Bench': ['Q Patel', 'M Wilson', 'L Davis']}
# Predicted Entity: {'Bench': ['Q Patel and M Wilson, L Davis']}
# True Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# Predicted Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# True Entity: {'Statute': ['IPC Section 136']}
# Predicted Entity: {'Statute': ['IPC Section 136']}
# True Entity: {'Statute': ['IPC Section 136'], 'Author': ['P Brown']}
# Predicted Entity: {'Statute': ['IPC Section 136 by P Brown']}
# True Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['Sentence upheld']}
# Predicted Entity: {'Statute': ['Income Tax Act'], 'Verdict': ['Sentence upheld']}
# True Entity: {'Bench': ['P Brown and Q Patel'], 'Statute': ['Evidence Act']}
# Predicted Entity: {'Bench': ['P Brown and Q Patel'], 'Statute': ['Evidence Act']}
# True Entity: {'Bench': ['Q Patel and M Wilson, L Davis']}
# Predicted Entity: {'Bench': ['Q Patel and M Wilson, L Davis']}
# True Entity: {'Bench': ['K Brown, L Wilson'], 'Statute': ['IPC Section 136']}
# Predicted Entity: {'Bench': ['K Brown, L Wilson'], 'Statute': ['IPC Section 136']}
# True Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# Predicted Entity: {'Statute': ['IPC Section 13'], 'wit$datetime': ['on 20th March, 2002']}
# True Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# Predicted Entity: {'Case_Name': ['The State vs. John Doe'], 'Statute': ['IPC Section 13']}
# Intent Metrics:
#
# Accuracy: 86.25%
# Precision: 86.25%
# Recall: 86.25%
# F-measure: 92.01%
#
# Entity Metrics:
#
# Accuracy: 81.25%
# Precision: 78.04%
# Recall: 76.25%
# F-measure: 76.25%

# %% [markdown]
# # CODE TO GENERATE QUERIES

# %%
import requests
from datetime import datetime
import re

wit_api_url = "https://api.wit.ai/message?v=1063283911477629&q=hello"
server_token = "MWLBURSN7OWE4F2ANHQ2P7L7QZVNJ6DH"

# Define your Cypher query templates based on recognized intents
QUERY_TEMPLATES = {
        "retrieve_case01": "MATCH (c:Case) WHERE {match_clause} RETURN c.Case_Name AS Case_Name;",
        "retrieve_precedent02": "MATCH (c:Case) WHERE {match_clause} RETURN c.Precedent AS Precedent;",
        "retrieve_statute03": "MATCH (c:Case) WHERE {match_clause} RETURN c.Statute;",
        "retrieve_date04": "MATCH (c:Case) WHERE {match_clause} RETURN c.Judgement_Date AS Judgement_Date;",
        "retrieve_author05": "MATCH (c:Case) WHERE {match_clause} RETURN c.Author AS Author;",
        "retrieve_bench06": "MATCH (c:Case) WHERE {match_clause} RETURN c.Bench AS Bench;",
        "retrieve_type07": "MATCH (c:Case) WHERE {match_clause} RETURN c.Case_Type AS Case_Type;",
        "retrieve_verdict08": "MATCH (c:Case) WHERE {match_clause} RETURN c.Verdict AS Verdict;",
        "summarize_case09": "MATCH (c:Case) WHERE {match_clause} RETURN c.Summary AS Summary;",
        "retrieve_alldeets10": "MATCH (c:Case) WHERE {match_clause} RETURN c.Case_Name as Case_Name, c.IPC as IPC, c.CRPC as CRPC, c.CPC as CPC, c.Acts as Acts, c.CaseID_CitationID as CaseID_CitationID ,c.Judgement_Date as Judgement_Date, c.Author as Author, c.Bench as Bench, c.Verdict as Verdict;"
    }

        # RETURN c.Case_Name, c.IPC, c.CRPC, c.CPC, c.Judgement_Date, c.Author, c.Bench, c.Verdict, c.Location;
    # Function to send a query to Wit.ai and extract intent and entities
def get_witai_intent_and_entities(query):
        headers = {
            "Authorization": f"Bearer {server_token}"
        }

        params = {
            "q": query
        }

        response = requests.get(wit_api_url, headers=headers, params=params)
        data = response.json()
        intent = data['intents'][0]['name'] if data['intents'] else None
        entities = data['entities']

        return intent, entities

    # Function to generate a Cypher query based on intent and entities
def generate_cypher_query(intent, entities):
        if intent in QUERY_TEMPLATES:
            query_template = QUERY_TEMPLATES[intent]

            # Generate the MATCH clause based on entities
            match_clause = ""
            for entity_name, entity_values in entities.items():
                # Assuming that each entity has only one value for simplicity
                entity_value = entity_values[0]['body']
                entity_name = entity_name.split(':')[0]

                if entity_name == 'wit$datetime' and 'on' in entity_value.lower():
                # Remove the word 'on' from the datetime value
                    entity_name = 'Judgement_Date'
                    entity_value = entity_value.replace('on', '').strip()

                if entity_name == 'Statute':

                    if 'IPC' in entity_value:
                        key, value = 'IPC', entity_value.split('IPC')[1].strip()
                        section_value = ''.join(filter(str.isdigit, entity_value))
                    elif 'CRPC' in entity_value:
                        key, value = 'CRPC', entity_value.split('CRPC')[1].strip()
                        section_value = ''.join(filter(str.isdigit, entity_value))
                    elif 'CPC' in entity_value:
                        key, value = 'CPC', entity_value.split('CPC')[1].strip()
                        section_value = ''.join(filter(str.isdigit, entity_value))
                    else:
                        key, value = 'Acts', None
                        section_value = ''.join(entity_value)

                    # Use the extracted Section value in the MATCH clause
                    match_clause += f" "
                    #{{{key}: '{section_value}'}})-"
                else:
                    match_clause += f" c.{entity_name}= '{entity_value}' and"

            # Remove the trailing "-"
            match_clause = match_clause.rstrip('and')

            # Replace placeholders with the generated MATCH clause
            cypher_query = query_template.format(match_clause=match_clause)
            if intent == 'retrieve_statute03':
                cypher_query = cypher_query.replace('c.Statute', f'c.IPC as IPC, c.CPC as CPC, c.CRPC as CRPC, c.Acts as Acts')

            # Add WHERE ANY clause for IPC, CPC, and CRPC after the MATCH clause
            if 'Statute' in entity_name:
                where_clauseIPC = f" ANY(ipc IN c.IPC WHERE ipc ='{section_value}')"
                where_clauseCPC = f" ANY(cpc IN c.CPC WHERE cpc ='{section_value}')"
                where_clauseCRPC = f" ANY(crpc IN c.CRPC WHERE crpc ='{section_value}')"
                where_clauseAct = f" ANY(act IN c.Acts WHERE act ='{section_value}')"
                if 'IPC' in entity_value and 'CRPC' not in entity_value and 'CPC' not in entity_value:
                    cypher_query = cypher_query.replace('RETURN', f'{where_clauseIPC}\nRETURN', 1)
                elif 'CPC' in entity_value and 'CRPC' not in entity_value and 'IPC' not in entity_value:
                    cypher_query = cypher_query.replace('RETURN', f'{where_clauseCPC}\nRETURN', 1)
                elif 'CRPC' in entity_value and 'IPC' not in entity_value and 'CPC' not in entity_value:
                    cypher_query = cypher_query.replace('RETURN', f'{where_clauseCRPC}\nRETURN', 1)
                else:
                    cypher_query = cypher_query.replace('RETURN', f'{where_clauseAct}\nRETURN', 1)

            # pattern = r'\bAND\b(?=\s*RETURN\b)'
            # cypher_query = re.sub(pattern, '', cypher_query)
            return cypher_query.strip()
        else:
            return "No intent template found"

user_query = "Find author citing 2003 AIR 1232 where Sentence upheld and CrPC Section 136"
witai_intent, witai_entities = get_witai_intent_and_entities(user_query)

if witai_intent:
    cypher_query = generate_cypher_query(witai_intent, witai_entities)
    if cypher_query:
        print("Entities:", witai_entities)
        print("Generated Cypher Query:", cypher_query)
        # return {'query': cypher_query}
    else:
        print("No Cypher query template found for the intent.")
else:
        print("No intent recognized.")
# Out:
# Entities: {'Statute:Statute': [{'body': 'CrPC Section 136', 'confidence': 0.9995, 'end': 75, 'entities': {}, 'id': '910665793817287', 'name': 'Statute', 'role': 'Statute', 'start': 59, 'type': 'value', 'value': 'CrPC Section 136'}], 'Verdict:Verdict': [{'body': 'Sentence upheld and', 'confidence': 0.999, 'end': 58, 'entities': {}, 'id': '368414782435853', 'name': 'Verdict', 'role': 'Verdict', 'start': 39, 'suggested': True, 'type': 'value', 'value': 'Sentence upheld and'}], 'wit$number:number': [{'body': '2003', 'confidence': 1, 'end': 23, 'entities': {}, 'id': '362178386402228', 'name': 'wit$number', 'role': 'number', 'start': 19, 'type': 'value', 'value': 2003}, {'body': '1232', 'confidence': 1, 'end': 32, 'entities': {}, 'id': '362178386402228', 'name': 'wit$number', 'role': 'number', 'start': 28, 'type': 'value', 'value': 1232}]}
# Generated Cypher Query: MATCH (c:Case) WHERE   c.Verdict= 'Sentence upheld and' and c.wit$number= '2003'  RETURN c.Author AS Author;
